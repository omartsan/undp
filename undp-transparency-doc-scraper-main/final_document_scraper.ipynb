# %%
#need to sudo apt-get install tesseract-ocr
#need to also install poppler-utils
from PIL import Image 
# import pytesseract 
import sys 
from pdf2image import convert_from_path 
import os 
import pandas as pd, math, inspect, requests
from lxml import html
import re, json, io
import textract
import urllib.parse
import scrapy
from scrapy.crawler import CrawlerProcess
from PyPDF2 import PdfFileReader
import os
import urllib
import ssl
import pdfpages
import pikepdf
#from docx2pdf import convert
from datetime import date
today = date.today().strftime("%Y-%m-%d")
import pdfplumber

# %%
#Document Folder Scraper
#Get the folders containing the documents
#Hast to be executed separately and independently of document list scraper
class BootstrapTableSpider(scrapy.Spider):
    name = "un_test"
    custom_settings = {
        'FEED_FORMAT': 'csv',
        'FEED_URI': 'temp-documentfolders.csv'
    }
    def start_requests(self):
        urls = ['https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx']
        for url in urls:
            yield scrapy.Request(url, self.parse)

    
    def parse(self, response):
        rows = response.css('.ms-vb')
    
        for row in rows:
            if row.css('a')[0].xpath('@href').extract_first().find('Forms')>0:
                yield {
                  'country_code' :  row.css('a::text').extract()[0],
                  'url' : 'https://info.undp.org' + row.css('a')[0].xpath('@href').extract_first() + '&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'
                  #'url' : 'https://info.undp.org' + row.css('a')[0].xpath('@href').extract_first() + '&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterField2=DocIcon&FilterValue2=pdf&FilterLookupId1=1&FilterOp1=In&FilterData1=0,099f975e-b4d9-4bba-a499-dbcc387c61ad&&SortField=ID&SortDir=Desc' 
                }

try:
    os.remove("temp-documentfolders.csv")
except:
    pass
                
process = CrawlerProcess();
process.crawl(BootstrapTableSpider);
process.start();
# Out:
# 2024-01-18 16:04:20 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2024-01-18 16:04:20 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.9.13, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.2 (v3.10.2:a58ebcc701, Jan 13 2022, 14:50:16) [Clang 13.0.0 (clang-1300.0.29.30)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform macOS-14.2.1-arm64-arm-64bit
# 2024-01-18 16:04:20 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-01-18 16:04:20 [py.warnings] WARNING: /Users/omarsantoyo/aid-transparency-tracker/.ve/lib/python3.10/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-01-18 16:04:20 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2024-01-18 16:04:20 [scrapy.extensions.telnet] INFO: Telnet Password: 3eb79e23bd9d4e57
# 2024-01-18 16:04:20 [py.warnings] WARNING: /Users/omarsantoyo/aid-transparency-tracker/.ve/lib/python3.10/site-packages/scrapy/extensions/feedexport.py:406: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2024-01-18 16:04:20 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-01-18 16:04:20 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2024-01-18 16:04:20 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-01-18 16:04:20 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-01-18 16:04:20 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-01-18 16:04:20 [scrapy.core.engine] INFO: Spider opened
# 2024-01-18 16:04:20 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-01-18 16:04:20 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-01-18 16:04:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx> (referer: None)
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'ABW', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FABW&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'AGO', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FAGO&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'AIA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FAIA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'ALB', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FALB&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'ANT', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FANT&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'ARE', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FARE&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'ARG', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FARG&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'ARM', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FARM&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'ATG', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FATG&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'AZE', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FAZE&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BDI', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBDI&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BEN', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBEN&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BFA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBFA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BGD', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBGD&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BGR', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBGR&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BHR', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBHR&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BHS', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBHS&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BIH', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBIH&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BLR', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBLR&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BLZ', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBLZ&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BMU', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBMU&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BOL', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBOL&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BRA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBRA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BRB', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBRB&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BRC', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBRC&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BTN', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBTN&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'BWA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FBWA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CAF', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCAF&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CHL', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCHL&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CHN', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCHN&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CIV', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCIV&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CMR', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCMR&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'COD', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCOD&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'COG', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCOG&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'COK', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCOK&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'COL', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCOL&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'COM', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCOM&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CPV', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCPV&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CRC', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCRC&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CRI', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCRI&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CUB', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCUB&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CUR', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCUR&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CUV', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCUV&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CYM', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCYM&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'CYP', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FCYP&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'DJI', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FDJI&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'DMA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FDMA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'DOM', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FDOM&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'DZA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FDZA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'ECU', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FECU&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'EGY', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FEGY&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'ERI', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FERI&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'ETH', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FETH&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'FJI', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FFJI&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'FSM', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FFSM&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'GAB', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FGAB&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'GEO', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FGEO&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'GHA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FGHA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'GIN', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FGIN&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'GMB', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FGMB&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'GNB', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FGNB&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'GNQ', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FGNQ&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'GRD', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FGRD&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'GTM', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FGTM&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'GUY', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FGUY&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H01', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH01&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H02', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH02&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H03', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH03&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H04', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH04&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H05', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH05&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H10', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH10&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H11', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH11&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H12', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH12&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H13', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH13&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H14', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH14&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H15', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH15&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H17', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH17&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H18', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH18&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H19', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH19&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H20', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH20&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'H21', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FH21&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# ...
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'SXM', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FSXM&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'SYC', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FSYC&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'SYR', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FSYR&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TCA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTCA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TCD', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTCD&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TGO', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTGO&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'THA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTHA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TJK', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTJK&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TKL', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTKL&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TKM', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTKM&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TLS', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTLS&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TON', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTON&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TTO', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTTO&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TUN', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTUN&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TUR', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTUR&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TUV', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTUV&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'TZA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FTZA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'UGA', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FUGA&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'UKR', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FUKR&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'UNV', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FUNV&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'URY', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FURY&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'UZB', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FUZB&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'VCT', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FVCT&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'VEN', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FVEN&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'VGB', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FVGB&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'VNM', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FVNM&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx>
# {'country_code': 'VUT', 'url': 'https://info.undp.org/docs/pdc/Documents/Forms/AllItems.aspx?RootFolder=%2Fdocs%2Fpdc%2FDocuments%2FVUT&FolderCTID=0x0120008F90FBF6FA09BA4B986DA533205DBD00&View={CD1390B8-D58D-4F86-B1E7-4FBEE9D956EA}&FilterField1=Atlas_x0020_Document_x0020_Type&FilterValue1=1110&FilterOp1=In&FilterLookupId1=1&FilterData1=0%2C099f975e-b4d9-4bba-a499-dbcc387c61ad&SortField=Created&SortDir=Desc'}
# 2024-01-18 16:04:23 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-01-18 16:04:23 [scrapy.extensions.feedexport] INFO: Stored csv feed (225 items) in: temp-documentfolders.csv
# 2024-01-18 16:04:23 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 252,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 941429,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 3.383832,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 1, 18, 22, 4, 23, 528672, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 225,
#  'log_count/DEBUG': 227,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 2,
#  'memusage/max': 161300480,
#  'memusage/startup': 161300480,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2024, 1, 18, 22, 4, 20, 144840, tzinfo=datetime.timezone.utc)}
# 2024-01-18 16:04:23 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
#Document List scraper. 
#Run after and independently of document folder scraper

#read existing document data
dfcsv = pd.read_csv('documents.csv')
dfcsv['doctype']=dfcsv['url'].str.split('.').str[-1].str.lower()

# %%
dfcsv = dfcsv[dfcsv['filename'].str.contains('00132553')==False]

# %%
#document list scraper
#get folders to scrape
dfolders = pd.read_csv('temp-documentfolders.csv')
os.remove("temp-documentfolders.csv")    #<-------------------------------<<<<------
folder_list = dfolders['url'].tolist()

class BootstrapTableSpider2(scrapy.Spider):
    name = "un_test"
    custom_settings = {
        'FEED_FORMAT': 'csv',
        'FEED_URI': 'temp-documents.csv'
    }

        
    def start_requests(self):
        
        urls = folder_list
        for url in urls:
            yield scrapy.Request(url, self.parse)

    
    def parse(self, response):
        rows = response.css('.ms-itmhover')
    
        for row in rows:
            if row.css('.ms-vb2')[5].css('td::text').extract_first()== 'Prodoc':
                row_id = row.css('.ms-vb').css('div').xpath('@id').extract_first()
                row_document_id = row.css('.ms-vb2')[6].css('a::text').extract_first()
                
                #if (dfcsv[dfcsv['id'].isin([row_id])].empty == True) & (dfcsv[dfcsv['document_id'].isin([row_document_id])].empty == True): 
                yield {
                      'filename' :  row.css('.ms-vb').css('a::text').extract_first(),
                      'title' : row.css('.ms-vb2')[0].css('td::text').extract_first(),
                      'id' : row.css('.ms-vb').css('div').xpath('@id').extract_first(),
                      'document_id' : row.css('.ms-vb2')[6].css('a::text').extract_first(),
                      'project_id' : row.css('.ms-vb2')[3].css('td::text').extract_first(),
                      'document_category' : row.css('.ms-vb2')[4].css('td::text').extract_first(),
                      'pdc_document_type' : row.css('.ms-vb2')[5].css('td::text').extract_first(),
                      'modified' : row.css('.ms-vb2')[7].css('nobr::text').extract_first(),
                      'created' : row.css('.ms-vb2')[8].css('nobr::text').extract_first(),
                      'operating_unit' : row.css('.ms-vb2')[2].css('td::text').extract_first(),
                      'url' : 'https://info.undp.org' + row.css('.ms-vb').css('a')[0].xpath('@href').extract_first(),
                }

try:
    os.remove("temp-documents.csv")
except:
    pass

# %%
# %%capture
process = CrawlerProcess();
process.crawl(BootstrapTableSpider2);
process.start();

# %%
#read new document data and append to existing
dfcsv_newdocs = pd.read_csv('temp-documents-riza.csv',  encoding='latin-1')
#os.remove("temp-documents.csv")
dfcsv_newdocs['doctype']=dfcsv_newdocs['url'].str.split('.').str[-1].str.lower()
newdoc = True

print(dfcsv_newdocs.values)
#dfcsv.loc[dfcsv['document_id'].isin(dfcsv_newdocs['document_id'])==False,'eval2']="fixed"
#dfcsv.loc[dfcsv['document_id'].isin(dfcsv_newdocs['document_id'])==False,'eval1']="fixed"
#dfcsv.loc[dfcsv['document_id'].isin(dfcsv_newdocs['document_id'])==False,'last_update']=today

dfcsv_newdocs['last_update'] = today

#if newdoc == True:
#    dfcsv = dfcsv.append(dfcsv_newdocs[dfcsv_newdocs['document_id'].isin(dfcsv['document_id'])==False],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[14], line 2
#       1 #read new document data and append to existing
# ----> 2 dfcsv_newdocs = pd.read_csv('temp-documents-riza.csv',  encoding='utf-8-sig')
#       3 #os.remove("temp-documents.csv")
#       4 dfcsv_newdocs['doctype']=dfcsv_newdocs['url'].str.split('.').str[-1].str.lower()
#
# File ~/.ve/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/.ve/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/.ve/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/.ve/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File ~/.ve/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:579, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:668, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2050, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x99 in position 1113: invalid start byte

# %%
dfcsv.columns

# %%
#fix any documents that have been removed by project managers:
dfcsv.loc[dfcsv['document_id'].isin(dfcsv_newdocs['document_id'])==False, 'url'] = 'Document deleted'
dfcsv.loc[dfcsv['document_id'].isin(dfcsv_newdocs['document_id'])==False, 'eval1'] = 'good'
dfcsv.loc[dfcsv['document_id'].isin(dfcsv_newdocs['document_id'])==False, 'eval1'] = 'ok'

# %%
#Score Criteria
#Score Keywords:
#Good if scroe >=4
project_title = ['project title','title of the program','title of program', 'award title', 'de projet', 'titulo proyecto', 'titulo de proyecto', 'título proyecto', 'de proyecto','titulo del proyecto', 'título del proyecto']
summary_desc = ['summary', 'project description', 'brief description','breve description', 'breve descripcion', 'breve descripción', 'resume de projet','resume', 'résumé', 'resumen']
project_id = ['award id', 'project no','project number','numero de projet','identifiant','du projet','numero proyecto','projecto id','número del proyecto','numero del proyecto']
implementing_partner = ['implementing partner', 'executing partner', 'implementing organization','implementing un organization', 'implementing organisation', 'implementing agenc', 'executing agenc', 'partenaire dexecution', 'partenaire d’exécution' ,'agence dexecution', 'agence d’exécution', 'agencia ejecutora', 'asociado en la implementación']
start_date = ['commencing date','start date', 'commencement date', 'starting date','start year','duration of program', 'period,duration', 'date de debut', 'date de début','periode', 'periodo','fecha de inicio', 'ano inicio' ]
end_date = ['ending date','end date', 'period end date', 'end year', 'project period','duration of program','project duration', 'date de fin', 'fin de periode', 'fin de période', 'fecha final', 'ano finalizacion','fecha de finalización','fecha de finalizacion']
budget = ['total budget','total resources', 'total fund', 'required budget', 'estimated resources', 'resources required', 'total','financial','budget requis', 'total financiamiento', 'total financiero','presupuesto']

#additional metrics to determine if document is "OK"
#If the document quality is good but the total page count is less than or equal to 4 pages, it will be “Not Ok”
#If the document quality is good and the total page count is more than 4, it is “Ok”

#if document good but not ok (<5 pages) if conecept note passed then change to OK.
concept_note = ['background','contexte','fondo','rationale','raisonnement','concept','concepto','situation analysis','documento de proyecto','document de projet','analyse de la situation','análisis de situación', 'initiation plan','plan de iniciación',"plan d'initiation"]

#if document >5 pages but not good: if project_document passes then document passes to OK & good.
project_document = ['project document', 'documento de proyecto', 'document de projet']

awp= ['annual work plan', 'plan de trabajo','anual plan','de travail annuel','combined delivery report', 'rapport de livraison combiné','informe de entrega combinado','cdr','awp']

#if bad  & >10 pages then review
# if bad  & >5 pages and (concept note or project note TRUE) then OK
#if bad & 5<pages<=10 then review
#if bad & 5<pages<=10 & awp = True  then bad

# %%
dic1 = {'√©': 'é',
'√°': 'á',
'√≠': 'í',
'√≥': 'ó',
'√∂': 'ö',
'√º': 'ü',
'√¥': 'ô',
'√®': 'è',
'√ß': 'ç',
'√±': 'ñ',
'√∏': 'ø',
'√´': 'ë',
'√§': 'ä',
'√•': 'å',
'√Å': 'Á',
'√∫': 'ú',
'√ª': 'û',
'√Ø': 'ï',
'√â': 'É',
'√†': 'à',
'√¶': 'æ',
'√Æ': 'î',
'√¢': 'â',
'√£': 'ã',
'√î': 'Ô',
'√ü': 'ß',
'√ì': 'Ó',
'√≤': 'ò',
'√Ω': 'ý',
'√ñ': 'Ö',
'√™': 'ê',
'√Ä': 'À',
'√ò': 'Ø',
'√Ö': 'Å',
'√∞': 'ð',
'√á': 'Ç',
'√Ç': 'Â',
'√π': 'ù',
'√í': 'Ò',
'√¨': 'ì',
'√ú': 'Ü',
'√à': 'È',
'√û': 'Þ',
'√ö':'Ú',
'°':'¬∞'}

# %%
for old, new in dic1.items():
    dfcsv['url'] = dfcsv['url'].str.replace(old, new, regex=False)

# %%
len(dfcsv[dfcsv['eval1'].isnull() & dfcsv['eval2'].isnull()])

# %%
i=0
for index,docrow in dfcsv[dfcsv['eval1'].isnull() & dfcsv['eval2'].isnull()].tail(1500).iterrows():
    i=i+1
    context = ssl._create_unverified_context()
    #print(docrow['url'])
    #download file - to do so need to replace spaces with defined spaces
    url = docrow['url']
    url = urllib.parse.urlsplit(url)
    url = list(url)
    url[2] = urllib.parse.quote(url[2])
    url = urllib.parse.urlunsplit(url)
    downloadfile = urllib.request.urlopen(url,context=context)
    
    page_content=""
    passer2 =""
    content_missing = ""
    
    #reading file, depending on filetype
    if docrow['doctype'] =='pdf':
        file = open("temp-file.pdf", 'wb')
        file.write(downloadfile.read())
        try:
            pdfReader = PdfFileReader("temp-file.pdf")
            passer = True
        except:
            print("A: File Corrupt: ", url)
            eval2 ='corrupt file'
            eval1 = 'bad'
            passer = False
        file.close()
        
        if passer == True:
            
            try:
                #counting pages
                pages = pdfReader.numPages

                #get content from first 5 pages
                for page_number in range(0,min(5,pages)):
                    page = pdfReader.getPage(page_number)
                    page_content += page.extractText().lower()
            except:
                try:
                    #sometimes it works the second time around
                    pages = pdfReader.numPages
                except:
                    try:
                        with pdfplumber.open("temp-file.pdf") as pdf:
                            pages = len(pdf.pages)
                    except:
                        pdf = pikepdf.Pdf.open('temp-file.pdf')
                        pages = len(pdf.pages)
                    
            try: #check if it is not ok or review, if that's the case runn through pike or plumber.
                project_title_cond  = bool([ele for ele in project_title if(ele in page_content)])
                summary_desc_cond  = bool([ele for ele in summary_desc if(ele in page_content)])
                project_id_cond  = bool([ele for ele in project_id if(ele in page_content)])
                implementing_partner_cond  = bool([ele for ele in implementing_partner if(ele in page_content)])
                start_date_cond  = bool([ele for ele in start_date if(ele in page_content)])
                end_date_cond  = bool([ele for ele in end_date if(ele in page_content)])
                budget_cond  = bool([ele for ele in budget if(ele in page_content)])
                project_document_cond = bool([ele for ele in project_document if(ele in page_content)])
                concept_note_cond = bool([ele for ele in concept_note if(ele in page_content)])
                awp_cond = bool([ele for ele in awp if(ele in page_content)])

                score = project_title_cond + summary_desc_cond +project_id_cond +implementing_partner_cond +start_date_cond +end_date_cond + budget_cond
            except:
                score = 0
            
            if pages == 0:
                try:
                    pdf = pikepdf.Pdf.open('temp-file.pdf')
                    pages = len(pdf.pages)
                except:
                    print("B: File corrupt", url)
                    passer2 = "fail"

            if ((len(page_content)<1000) & (passer2 !="fail")) | score<4:
                try:
                    file_out = open("temp-file-5p.pdf", 'wb')
                    file_in = [open("temp-file.pdf", "rb")]
                    pdfpages.extract(file_in, file_out, list(range(1,min(pages+1,6))))
                    file_out.close()
                    filoeoutname = 'temp-file-5p.pdf'
                except:
                    filoeoutname = 'temp-file.pdf'
                
                try:
                    with pdfplumber.open(filoeoutname) as pdf:
                        for pdf_page in pdf.pages:
                            page_content = page_content + pdf_page.extract_text()
                    page_content = str(page_content.lower())

                    os.remove("temp-file-5p.pdf")
                except:
                    try:
                        os.remove("temp-file-5p.pdf")
                        file_out = open("temp-file-5p.pdf", 'wb')
                        file_in = [open("temp-file.pdf", "rb")]
                        pdfpages.extract(file_in, file_out, list(range(1,2)))
                        file_out.close()
                        filoeoutname = 'temp-file-5p.pdf'
                        
                        
                        
                        with pdfplumber.open(filoeoutname) as pdf:
                            for pdf_page in pdf.pages:
                                page_content = page_content + pdf_page.extract_text()
                        page_content = str(page_content.lower())
                        
                        os.remove("temp-file-5p.pdf")
                    except:
                        try:
                            page_content = ""
                            with pdfplumber.open("temp-file.pdf") as pdf:
                                for pdf_page in pdf.pages:
                                    page_content = page_content + pdf_page.extract_text()
                            page_content = str(page_content.lower())
                        except:
                            try: 
                                page_content = textract.process(
                                    "temp-file.pdf",
                                    method='tesseract',
                                    language='eng',
                                )
                                page_content = str(page_content.lower())
                            except:
                                page_content =""
                                content_missing = "review"
                                print("Unable to read file.")
                        
                        
                    
            
        os.remove("temp-file.pdf")
        
    elif docrow['doctype'] == 'docx':
        file = open("temp-file.docx", 'wb')
        file.write(downloadfile.read())

        text = textract.process("temp-file.docx")
        file.close()
        os.remove("temp-file.docx")
        
        #estimate number of pages based on character count. This is not accurate, but approximate
        pages = round(len(text)/2000)
        
        #get content from first 5 pages (approx)
        page_content = str(text[0:12000]).lower()
        
    elif docrow['doctype'] == 'doc':
        try:
            try:
                file = open("temp-file.doc", 'wb')
                file.write(downloadfile.read())

                text = textract.process("temp-file.doc")
                file.close()
                os.remove("temp-file.doc")

                #estimate number of pages based on character count. This is not accurate, but approximate
                pages = round(len(text)/2000)

                #get content from first 5 pages (approx)
                page_content = str(text[0:12000]).lower()
            except:
                try:
                    file.close()
                except:
                    pass
                try:
                    os.remove("temp-file.doc")
                except:
                    pass
                file = open("temp-file.docx", 'wb')
                file.write(downloadfile.read())

                text = textract.process("temp-file.docx")
                file.close()
                os.remove("temp-file.docx")

                #estimate number of pages based on character count. This is not accurate, but approximate
                pages = round(len(text)/2000)

                #get content from first 5 pages (approx)
                page_content = str(text[0:12000]).lower()
        except:
            print("C: File corrupt: ", url)
        
    else:
        page_content = ""
        pages = 0
        
    #Scoring mechanism based on keyword searches    
    project_title_cond  = bool([ele for ele in project_title if(ele in page_content)])
    summary_desc_cond  = bool([ele for ele in summary_desc if(ele in page_content)])
    project_id_cond  = bool([ele for ele in project_id if(ele in page_content)])
    implementing_partner_cond  = bool([ele for ele in implementing_partner if(ele in page_content)])
    start_date_cond  = bool([ele for ele in start_date if(ele in page_content)])
    end_date_cond  = bool([ele for ele in end_date if(ele in page_content)])
    budget_cond  = bool([ele for ele in budget if(ele in page_content)])
    project_document_cond = bool([ele for ele in project_document if(ele in page_content)])
    concept_note_cond = bool([ele for ele in concept_note if(ele in page_content)])
    awp_cond = bool([ele for ele in awp if(ele in page_content)])

    score = project_title_cond + summary_desc_cond +project_id_cond +implementing_partner_cond +start_date_cond +end_date_cond + budget_cond

    if score>=4:
        eval1 = 'good'
    else:
        eval1 = 'bad'

    if (pages>4) & (eval1 == 'good'):
        eval2 = 'ok'
    else:
        eval2 = 'not ok'

    if (eval1 == 'good') & (eval2 == 'not ok'):
        if concept_note_cond == True:
            eval2 = 'ok'

    if (eval1 == 'bad') & (eval2 == 'ok'):
        if project_document_cond == True:
            eval1 = 'good'
            
    if (eval1 == 'bad')  & (pages >10 ):
        eval2 = 'review'
        
    if (eval1 == 'bad')  & (pages >5 ) & ((concept_note_cond ==True ) | (project_document_cond ==True )):
        eval2 = 'ok'
        
    if (eval1 == 'bad')  & (pages >2 ) & (concept_note_cond ==True ): #new
        eval2 = 'ok'

    if (eval1 == 'bad') & (pages >5 ) & (pages <11 ) & (awp != True) :
        eval2 = 'review'
        
    if (eval1 == 'bad') & (pages >5 ) & (pages <11 ) & (awp == True) :
        eval1 = 'bad'
    
    if (content_missing == "review") & (eval2 == "not ok") :
        eval2 = "review"

    
    dfcsv.loc[index,'eval1'] = eval1
    dfcsv.loc[index,'eval2'] = eval2
    dfcsv.loc[index,'score'] = score
    dfcsv.loc[index,'pages'] = pages
    dfcsv.loc[index,'project_title_cond'] = project_title_cond
    dfcsv.loc[index,'summary_desc_cond'] = summary_desc_cond
    dfcsv.loc[index,'project_id_cond'] = project_id_cond
    dfcsv.loc[index,'implementing_partner_cond'] = implementing_partner_cond
    dfcsv.loc[index,'start_date_cond'] = start_date_cond
    dfcsv.loc[index,'end_date_cond'] = end_date_cond
    dfcsv.loc[index,'budget_cond'] = budget_cond
    dfcsv.loc[index,'concept_note_cond'] = concept_note_cond
    dfcsv.loc[index,'project_document_cond'] = project_document_cond
    dfcsv.loc[index,'awp_cond'] = awp_cond
    
    #print(eval1,eval2)
    print(str(i) + ": " + eval2)

# %%
dfcsv['project_id'] = dfcsv['project_id'].apply(lambda x: x.zfill(8))
dfcsv.to_csv('documents.csv',index=False)

# %%
#import those documents that need to be overwritten:
revised_docs_riza = pd.read_excel('Revised_documents Riza.xlsx')

# %%
for index,row in dfcsv.iterrows():
    if len(revised_docs_riza[revised_docs_riza['document_id']==row['document_id']])>0:
        dfcsv.loc[dfcsv['document_id'] ==row['document_id'],'eval2'] = revised_docs_riza[revised_docs_riza['document_id'] ==row['document_id']]['revised_quality'].values[0]

# %%
dfcsv.to_csv('documents.csv',index=False)

# %%
dfcsv[dfcsv['document_id'].isin(revised_docs_riza['document_id'])]['eval2']
